# %% [markdown]
# # Statistics Project Stroop Effeect

# %% [markdown]
# #  Background Information

# %% [markdown]
# In a Stroop task, participants are presented with a list of words, with each word displayed in a color of ink. The participant’s task is to say out loud the color of the ink in which the word is printed. The task has two conditions: a congruent words condition, and an incongruent words condition. In the congruent words condition, the words being displayed are color words whose names match the colors in which they are printed: In the incongruent words condition, the words displayed are color words whose names do not match the colors in which they are printed. In each case, we measure the time it takes to name the ink colors in equally-sized lists. Each participant will go through and record a time from each condition.

# %% [markdown]
# # Method :
# I used pandas, numpy  seaborn and matplotlib libraries for analysis and visualization and dependent paired T-test statistical test of the experiment.

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, Series
import seaborn as sns
import pandas as pd
import scipy as sp

# %%
data= pd.read_csv("//Users/eyobe/Desktop/UDML/stroopdata.csv")

# %%
#data=data1[data1.Incongruent!=35].copy()
data.head()
# Out:
#    Congruent  Incongruent
# 0     12.079       19.278
# 1     16.791       18.741
# 2      9.564       21.214
# 3      8.630       15.687
# 4     14.669       22.803

# %% [markdown]
# # Questions For Investigation
#
# 1. What is our independent variable? What is our dependent variable?
# 2. What is an appropriate set of hypotheses for this task? What kind of statistical test do you expect to perform? Justify your choices.
# 3. Report some descriptive statistics regarding this dataset. Include at least one measure of central tendency and at least one measure of variability.
# 4
# . Provide one or two visualizations that show the distribution of the sample data. Write one or two sentences noting what you observe about the plot or plots.
# 5. Now, perform the statistical test and report your results. What is your confidence level and your critical statistic value? Do you reject the null hypothesis or fail to reject it? Come to a conclusion in terms of the experiment task. Did the results match up with your expectations?
# 6. Optional: What do you think is responsible for the effects observed? Can you think of an alternative or similar task that would result in a similar effect? Some research about the problem will be helpful for thinking about these two questions!
#
# $\textbf{Answer}$
# 1. The independent variable in the experiment is whether the words are congruent or incongruent and the dependent variable is the amount of time taken to name the color of the words.
#
# 2. Let $\mu_{C}$ be the  population mean of the reaction time for naming congruent words;
#
#    Let $\mu_{IC}$ be the  population mean of the reaction time for naming incongruent words;
#
#    The appropriate set of  hypotheses for this experiment can be given by:
#
# Null Hypothesis (H$_{O}$):
#
# The average population reaction time to name the colors is the same for $\textit{congruent}$ and $\textit{incongruent}$ words.
#
# Alternate Hypothesis (H$_{A}$):
#
# The average population reaction time to name the colors is different for $\textit{congruent}$ and $\textit{incongruent}$ words.
#
# $\textbf{Mathematically;}$
#
#    $H_{O}$ : $\mu_{C}$= $\mu_{IC}$
#
#    $H_{A}$ : $\mu_{C}$ $\neq$ $\mu_{IC}$
#
#  Since the two tests are performed on the same subject (participants) but with two different conditions $\textit{i.e}$,$\textbf{Congruent}$ and $\textbf{Incongruent}$ words the samples are paired. More over the sample size is 25 which is small. For the two  mentioned reasons the appropriate  statistical test for this experiment is dependent two-tailed paired T-test.
#
# 3.1. The means of the reaction times of (Congruent and Incongruent words are :
#
#        (Congruent, Incongruent)= (14.051125000000004, 22.01591666666667)
#
# 3.2. The standarad deviations of the reaction times of Congruent and Incongruent words are :
#
#       (Congruent, Incongruent)= (3.559357957645195, 4.797057122469138)
#
# 3.3. The medians of the reaction times of Congruent and Incongruent words are :
#
#      (Congruent, Incongruent)= (14.3565, 21.0175)
#
# 3.4. The ranges of the reaction times of Congruent and Incongruent words are :
#
#      (Congruent, Incongruent)= (13.698000000000002, 19.568000000000001)
#
# 3.5. The Inter-quantile ranges of the reaction times of Congruent and Incongruent words are :
#
#      (Congruent, Incongruent)= (4.3054999999999986, 5.3347499999999997)

# %% [markdown]
#  # Investigation of the data

# %%
print "The means of the reaction times of Congruent and Incongruent words are  :\n \
(Congruent_mean, Incongruent_mean)=" '({}, {})'.format(data["Congruent"].mean(),data["Incongruent"].mean())
print'\n'
print "The standarad deviations of the reaction times of Congruent and Incongruent words are :\n\
(Congruent_sd, Incongruent_sd)="'({}, {})'.format(data["Congruent"].std(),data["Incongruent"].std())
print'\n'
print "The medians of the reaction times of Congruent and Incongruent words are :\n\
(Congruent_median, Incongruent_median)="'({}, {})'.format(data["Congruent"].median(),data["Incongruent"].median())
print'\n'
print "The ranges of the reaction times of Congruent and Incongruent words are : \n \
(Congruent_range, Incongruent_range)="'({}, {})'.format(data["Congruent"].max()-data["Congruent"].min(),data["Incongruent"].max()-data["Incongruent"].min())
print '\n'
print "The Inter-quantile ranges of the reaction times of Congruent and Incongruent words are :\n \
(Congruent_interquantile_range, Incongruent_interquantile_range)="'({}, {})'.format(data["Congruent"].quantile(0.75)-data["Congruent"].quantile(0.25), data["Incongruent"].quantile(0.75)-data["Incongruent"].quantile(0.25))
# Out:
# The means of the reaction times of Congruent and Incongruent words are  :
#  (Congruent_mean, Incongruent_mean)=(14.051125, 22.0159166667)
#
#
# The standarad deviations of the reaction times of Congruent and Incongruent words are :
# (Congruent_sd, Incongruent_sd)=(3.55935795765, 4.79705712247)
#
#
# The medians of the reaction times of Congruent and Incongruent words are :
# (Congruent_median, Incongruent_median)=(14.3565, 21.0175)
#
#
# The ranges of the reaction times of Congruent and Incongruent words are :
#  (Congruent_range, Incongruent_range)=(13.698, 19.568)
#
#
# The Inter-quantile ranges of the reaction times of Congruent and Incongruent words are :
#  (Congruent_interquantile_range, Incongruent_interquantile_range)=(4.3055, 5.33475)

# %% [markdown]
# From the calculations of the central tendencies and variability of the data, it is clearly shown that the mean time to name the colors of congruent words is shorter than the mean time to name the color of incongruent words. This is explained by the overall time taken by students to name the congruent words is shorter compared to the incongruent. The calculated variability of the time taken to name the colors of the incongruent words is higher than the congruent ones as can be seen from the calculated standard deviation, range and interquantile range.

# %% [markdown]
# # 3.5. Outliers
# Are there any outliers in the data? In order to answer this questin we calculated the inter quartile difference and  found the data points that lie out of the range of (the lower 25 % qurtile (25 % quantile) - 1.5$*$Inter_quantile_range, the lower upper 25% qurtile (75 % quantile) + 1.5$*$Inter_quantile_range ). From this investigation it is found that the data with incongruent words contains two outlier data points [35.255000000000003, 34.288000000000004] which fall out of the interval (10.714625000000002, 32.053624999999997). The detailed calculation is shown in the notebook below.

# %%
#(data["Congruent"].mean(),data["Incongruent"].mean())

# %%
Inter_quantile_range=data.quantile(0.75)-data.quantile(0.25)

Congruent_non_outlier_range=(data["Congruent"].quantile(0.25)-1.5*Inter_quantile_range["Congruent"], \
                         
                data["Congruent"].quantile(0.75)+1.5*Inter_quantile_range["Congruent"])
#
Incongruent_non_outlier_range=(data["Incongruent"].quantile(0.25)-1.5*Inter_quantile_range["Incongruent"],\
                           
                data["Incongruent"].quantile(0.75)+1.5*Inter_quantile_range["Incongruent"])

print "The Congruent_outlier_range is:", Congruent_non_outlier_range

print "The Incongruent_outlier_range is:",Incongruent_non_outlier_range
#Inter_quantile_range
# Out:
# The Congruent_outlier_range is: (5.4370000000000029, 22.658999999999999)
# The Incongruent_outlier_range is: (10.714625000000002, 32.053624999999997)

# %%
lower_lim_Con=data["Congruent"].quantile(0.25)-1.5*Inter_quantile_range["Congruent"]

upper_lim_Con=data["Congruent"].quantile(0.75)+1.5*Inter_quantile_range["Congruent"]  

lower_lim_Incon=data["Incongruent"].quantile(0.25)-1.5*Inter_quantile_range["Incongruent"]

upper_lim_Incon=data["Incongruent"].quantile(0.75)+1.5*Inter_quantile_range["Incongruent"]

# %%
Congruent_outlier =[value for value in data["Congruent"] if value > upper_lim_Con or value < lower_lim_Con]

Incongruent_outlier = [value for value in data["Incongruent"] if value > upper_lim_Incon or value < lower_lim_Incon]

print "The outlers in the Congruent data = ", Congruent_outlier

print "The outlers in the Incongruent data = ", Incongruent_outlier
# Out:
# The outlers in the Congruent data =  []
# The outlers in the Incongruent data =  [35.255000000000003, 34.288000000000004]

# %% [markdown]
# # 3.6. Visualizations and analysis

# %%
#data.max()-data.min()
#data["Congruent"].plot(kind= "area")
ax = data.plot(kind="area")
ax.set_xlabel("Participant ID")
ax.set_ylabel("Reaction Time")

# %%
sns.set(font_scale=2)
sns.set_style("whitegrid")
#sns.set_context("paper")

plt.figure(figsize=(8,6))
ax=sns.boxplot(data=data)
ax.set(xlabel='Word Type', ylabel='Time To Read')
#plt.figure(figsize=(6,4))
#ax = sns.barplot( data=data, capsize=.1,label='big')
#ax.set(xlabel='Word Type', ylabel='Time To Read')
plt.show()
#plt.show()

# %%
#sns.set(font_scale=2)
#plt.figure(figsize=(10,8))
#ax = sns.barplot( data=data, capsize=.1,label='big')
#ax.set(xlabel='Word Type', ylabel='Time To Read')
#plt.show()

# %%
plt.figure(figsize=(8,6))
x=data["Congruent"].values
y=data["Incongruent"].values
ax=sns.distplot(x,bins=20, kde=True, rug=True,kde_kws={"color": "r", "label": "Congruent KDE","lw": 5},hist_kws={ "linewidth": 3, "label": "Congruent",  "alpha": 0.5, "color": "g"})
ax.set(xlabel='Time To Read')#,'Word Type', ylabel='Time To Read')
ay=sns.distplot(y,bins=20, kde=True, rug=True,kde_kws={"color": "b", "lw": 5,"label": "Incongruent KDE"},hist_kws={ "linewidth": 3, "label": "Incongruent",  "alpha": 0.5, "color": "m"})
ay.set(xlabel='Time To Read')#'Word Type', ylabel='Time To Read')
plt.show()

# %% [markdown]
# From the box plot shown above, we can see that the central tendency of the reaction time to name the colors  in congruent words is less than that of incongruent words. The two points that lie out of the maximum value of the box plot in the incongruent reaction time data are the outliers consistent with our previous calculation. The  distribution of the reaction times for both congruent and incongruent words is also plotted above with its corrosponding kernel density approximation (KDE). As we can see from the figure the two distributions have different central tendencies and the distribution of the congruent data set falls below the incongruent one. The deviation from approximate T-distribution in the KDE of the incongruent data set is attributed to the outlier data points lie well above the interquntile range.

# %%
data["difference"]=data["Incongruent"]-data["Congruent"]
data.head()
# Out:
#    Congruent  Incongruent  difference
# 0     12.079       19.278       7.199
# 1     16.791       18.741       1.950
# 2      9.564       21.214      11.650
# 3      8.630       15.687       7.057
# 4     14.669       22.803       8.134

# %% [markdown]
# # 4. Statistical Test
# The appropriate set of  hypotheses for this experiment are:
#
#    $H_{O}$ : $\mu_{C}$= $\mu_{IC}$
#
#    $H_{A}$ : $\mu_{C}$ $\neq$ $\mu_{IC}$
#
# Let,
#      $X_{C}$ = The sample mean of the reaction time for congruent words, and
#      $X_{IC}$ = The sample mean of the reaction time for incongruent words;
#
#
#   Then  the point estimate of the the population mean difference $\mu_{C}$$-$$\mu_{IC}$ = $X_{C}$$-$$X_{IC}$ =7.96479166667.
#
#   Our T-statistics test then given by:
#
#   t = ($X_{C}$$-$$X_{IC}$)/($S_{D}$/$\sqrt n$)
#
#  Where n =25, is our sample size, and $S_{D}$ is the standard error of the difference of the sample calculated below.
#
#  Lets first create another column (the difference) in our data frame to calculate the standard error $S_{D}$.

# %%
data["difference"]=data["Incongruent"]-data["Congruent"]
data.head()
SD=data["difference"].std()
D= data["difference"].mean()
print "The standard error of the difference =", SD
t=(data["Incongruent"].mean()-data["Congruent"].mean())/(SD/np.sqrt(24))
print "The t_value = %4.2f" % t
#print "The mean of the difference =",D
#SD=np.sqrt(np.sum((data["difference"]-data["difference"].mean())**2)/23)
#t=(data["Incongruent"].mean()-data["Congruent"].mean())/(SD/np.sqrt(24))
# Out:
# The standard error of the difference = 4.86482691036
# The t_value = 8.02

# %% [markdown]
# With 95 % confidence level, the critical t value ($t_{Critical}$$=$$\pm$ 2.064) and our two-tailed coupled  T-test value is 8.02 which lies in the rejection region. Hence, we reject the null hypothesis the population means of the reaction times  to name congruent and incongruent words are the same ($H_{O}$). This shows there is significant difference in the population mean of the reaction times to name the colors of words when the words are congruent and incongruent. The test result is consistent with our previous analysis and expected since our results from the calculated central tendencies of the samples show significant differences.
#
# This result shows that  partcipants react fast  to name the colors if the words  are congruent. The reaction time might also be affected by the reading ability of participants. Participants with reading problems might react slowly compared to others in congruent words.

# %%
#(data["Incongruent"]-data["Congruent"]).std()

# %%
#SD=np.sqrt(np.sum((data["difference"]-data["difference"].mean())**2)/23)

# %%
#SD

# %%
#t=(data["Incongruent"].mean()-data["Congruent"].mean())/(SD/np.sqrt(24))

# %%
#t
